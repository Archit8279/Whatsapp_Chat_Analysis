# %%
import re
import pandas as pd
from datetime import datetime as dt

# %%
f= open('WhatsApp_friends_group_chat.txt','r', encoding = 'utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 28/09/21, 8:15 pm - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 14/12/16, 6:58 pm - Nishant created group "Back benchers"
# 28/09/21, 8:15 pm - Harshit added you
# 28/09/21, 8:15 pm - Manish: Tannu
# 28/09/21, 8:15 pm - Manish: ?
# 28/09/21, 8:15 pm - Harshit: Wo hua nhi
# 28/09/21, 8:15 pm - Harshit: Invitation bheja h
# 28/09/21, 8:15 pm - Manish: Hmm
# 28/09/21, 8:15 pm - Harshit: Gro ka
# 28/09/21, 8:17 pm - Harshit added Tanu
# 28/09/21, 8:21 pm - Harshit: A K Farms
# 092195 66755
# https://maps.app.goo.gl/WXd8zQk1RKHS9qhp7
# 28/09/21, 8:21 pm - Harshit: <Media omitted>
# 28/09/21, 8:22 pm - Harshit: Sb log invited ho or sunday ko mil lena sb
# 28/09/21, 9:23 pm - Manish: 👍
# 28/09/21, 9:28 pm - Shivam: https://www.instagram.com/reel/CUHvTB_Im52/?utm_medium=share_sheet
# 28/09/21, 9:33 pm - Shivam: https://www.instagram.com/reel/CT6Z1Kvgvp3/?utm_medium=share_sheet
# ...

# %%
# Regex to split messages on timestamp
pattern = r"(\d{1,2}/\d{1,2}/\d{2},\s\d{1,2}:\d{2}(?:\u202f|\s)?[ap]m)\s[-–]\s"

# Split messages
messages = re.split(pattern, data)[1:]

# Group into triplets: [datetime1, message1, datetime2, message2, ...]
# So we take even indexes as datetime, odd indexes as message
dates = messages[0::2]
msgs = messages[1::2]

user_messages = []
formatted_dates = []

for date_str, message in zip(dates, msgs):
    try:
        dt = dt.strptime(date_str.strip(), "%d/%m/%y, %I:%M %p")
    except ValueError:
        continue  # skip malformed timestamps

    # Extract user and message
    if ':' in message:
        user, msg = message.split(":", 1)
    else:
        user = "group_notification"
        msg = message

    user_messages.append({'date': dt, 'user': user.strip(), 'message': msg.strip()})

# Create DataFrame
df = pd.DataFrame(user_messages)

# Preview
df.head()
# Out:
#                  date                user  \
# 0 2021-09-28 20:15:00  group_notification
# 1 2016-12-14 18:58:00  group_notification
# 2 2021-09-28 20:15:00  group_notification
# 3 2021-09-28 20:15:00              Manish
# 4 2021-09-28 20:15:00              Manish
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. O...
# 1              Nishant created group "Back benchers"
# 2                                  Harshit added you
# 3                                              Tannu
# 4                                                  ?

# %%
df.shape
# Out:
# (6713, 3)

# %%
df
# Out:
#                     date                user  \
# 0    2021-09-28 20:15:00  group_notification
# 1    2016-12-14 18:58:00  group_notification
# 2    2021-09-28 20:15:00  group_notification
# 3    2021-09-28 20:15:00              Manish
# 4    2021-09-28 20:15:00              Manish
# ...                  ...                 ...
# 6708 2025-07-10 10:23:00             Nishant
# 6709 2025-07-16 16:15:00             Nishant
# 6710 2025-07-22 10:15:00             Harshit
# 6711 2025-07-22 10:16:00             Harshit
# 6712 2025-07-22 12:03:00              Manish
#
#                                                 message
# 0     Messages and calls are end-to-end encrypted. O...
# 1                 Nishant created group "Back benchers"
# 2                                     Harshit added you
# 3                                                 Tannu
# 4                                                     ?
# ...                                                 ...
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month_name()
df['day']=df['date'].dt.day
df['hour']=df['date'].dt.hour
df['minute']=df['date'].dt.minute

df.head()
# Out:
#                  date                user  \
# 0 2021-09-28 20:15:00  group_notification
# 1 2016-12-14 18:58:00  group_notification
# 2 2021-09-28 20:15:00  group_notification
# 3 2021-09-28 20:15:00              Manish
# 4 2021-09-28 20:15:00              Manish
#
#                                              message  year      month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2021  September   28
# 1              Nishant created group "Back benchers"  2016   December   14
# 2                                  Harshit added you  2021  September   28
# 3                                              Tannu  2021  September   28
# 4                                                  ?  2021  September   28
#
#    hour  minute
# 0    20      15
# 1    18      58
# 2    20      15
# 3    20      15
# 4    20      15
